# %% [markdown]
# # Initial EDA

# %%
import os

# change to your GitHub repo folder on D:
os.chdir(f"D:\Github Docs\SF-Budget-Intelligence-Forecasting-Compliance-and-Insights")

# confirm
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: D:\Github Docs\SF-Budget-Intelligence-Forecasting-Compliance-and-Insights

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import pandas as pd

# The original dataset (~140MB) was too large for GitHub.
# It has been split into two parts: Budget_20250921-1.csv and Budget_20250921-2.csv
# We combine them here into a single DataFrame for analysis.

df1 = pd.read_csv("data/raw/Budget_20250921-1.csv")
df2 = pd.read_csv("data/raw/Budget_20250921-2.csv")

# Concatenate the two halves into one DataFrame
df = pd.concat([df1, df2], ignore_index=True)

# Quick check of the combined dataset
df.head()
# Out:
# C:\Users\tulan\AppData\Local\Temp\ipykernel_12012\2767650657.py:8: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("data/raw/Budget_20250921-2.csv")
#    Fiscal Year Revenue or Spending Related Govt Unit  Organization Group Code  \
# 0         2018            Spending          Spending                        3
# 1         2018            Spending          Spending                        3
# 2         2018            Spending          Spending                        3
# 3         2018            Spending          Spending                        3
# 4         2018            Spending          Spending                        6
#
#                          Organization Group Department Code  \
# 0  Human Welfare & Neighborhood Development             CSS
# 1  Human Welfare & Neighborhood Development             CHF
# 2  Human Welfare & Neighborhood Development             CHF
# 3  Human Welfare & Neighborhood Development             CHF
# 4          General Administration & Finance             TIS
#
#                              Department Program Code  \
# 0                Child Support Services          CAF
# 1      Children, Youth & Their Families          FAY
# 2      Children, Youth & Their Families          CVP
# 3      Children, Youth & Their Families          CVP
# 4  General Services Agency - Technology          BTO
#
#                              Program Character Code  \
# 0     Child Support Services Program            013
# 1   Transitional-Aged Youth Baseline            038
# 2                Violence Prevention            038
# 3                Violence Prevention            013
# 4  Technology Services:Public Safety            013
#
#                    Character Object Code               Object Sub-object Code  \
# 0  Mandatory Fringe Benefits         015       Health Service           01599
# 1        City Grant Programs         038  City Grant Programs           03800
# 2        City Grant Programs         038  City Grant Programs           03801
# 3  Mandatory Fringe Benefits         014      Social Security           01401
# 4  Mandatory Fringe Benefits         013           Retirement           01301
#
#                                  Sub-object Fund Type Code  \
# 0                    Health Service - Other             2S
# 1  Community Based Organization Svcs-Budget             1G
# 2     Community Based Organization Services             2S
# 3              Social Security (OASDI & HI)             2S
# 4                          Retire City Misc             6I
#
#                 Fund Type Fund Code                               Fund  \
# 0   Special Revenue Funds     2SCSS        Child Support Services Fund
# 1            General Fund     1GAGF                       General Fund
# 2   Special Revenue Funds     2SPPF             Public Protection Fund
# 3   Special Revenue Funds     2SPPF             Public Protection Fund
# 4  Internal Service Funds     6ITIF  Telecomm. & Information Svcs Fund
#
#    Fund Category Code    Fund Category     Budget              data_as_of  \
# 0                 1.0        Operating    351,752  2025/09/14 10:06:00 PM
# 1                 2.0  Annual Projects    871,030  2025/09/14 10:06:00 PM
# 2                 4.0           Grants  2,590,396  2025/09/14 10:06:00 PM
# 3                 4.0           Grants     30,240  2025/09/14 10:06:00 PM
# 4                 1.0        Operating  1,096,350  2025/09/14 10:06:00 PM
#
#            data_loaded_at
# 0  2025/09/15 01:56:26 AM
# 1  2025/09/15 01:56:26 AM
# 2  2025/09/15 01:56:26 AM
# 3  2025/09/15 01:56:26 AM
# 4  2025/09/15 01:56:26 AM

# %%
# Shape of the dataset
print("Rows:", df.shape[0], "Columns:", df.shape[1])

# Data types and non-null counts
df.info()
# Out:
# Rows: 379557 Columns: 24
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379557 entries, 0 to 379556
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Fiscal Year              379557 non-null  int64
#  1   Revenue or Spending      379557 non-null  object
#  2   Related Govt Unit        379557 non-null  object
#  3   Organization Group Code  379557 non-null  int64
#  4   Organization Group       379557 non-null  object
#  5   Department Code          379557 non-null  object
#  6   Department               379557 non-null  object
#  7   Program Code             379557 non-null  object
#  8   Program                  379557 non-null  object
#  9   Character Code           379557 non-null  object
#  10  Character                379557 non-null  object
#  11  Object Code              379557 non-null  object
#  12  Object                   379557 non-null  object
#  13  Sub-object Code          379557 non-null  object
#  14  Sub-object               379557 non-null  object
#  15  Fund Type Code           379557 non-null  object
#  16  Fund Type                379557 non-null  object
#  17  Fund Code                379557 non-null  object
#  18  Fund                     379556 non-null  object
#  19  Fund Category Code       379535 non-null  float64
#  20  Fund Category            379535 non-null  object
#  21  Budget                   379557 non-null  object
#  22  data_as_of               379557 non-null  object
#  23  data_loaded_at           379557 non-null  object
# dtypes: float64(1), int64(2), object(21)
# memory usage: 69.5+ MB

# %%
# Count missing values per column
df.isna().sum()
# Out:
# Fiscal Year                 0
# Revenue or Spending         0
# Related Govt Unit           0
# Organization Group Code     0
# Organization Group          0
# Department Code             0
# Department                  0
# Program Code                0
# Program                     0
# Character Code              0
# Character                   0
# Object Code                 0
# Object                      0
# Sub-object Code             0
# Sub-object                  0
# Fund Type Code              0
# Fund Type                   0
# Fund Code                   0
# Fund                        1
# Fund Category Code         22
# Fund Category              22
# Budget                      0
# data_as_of                  0
# data_loaded_at              0
# dtype: int64

# %%
# Total duplicate rows
print("Duplicate rows:", df.duplicated().sum())

# Check duplicates by key fields (adjust based on dictionary)
dup_keys = df.duplicated(subset=["Fiscal Year", "Department", "Fund", "Program"])
print("Duplicates by Fiscal Year + Department + Fund + Program:", dup_keys.sum())
# Out:
# Duplicate rows: 0
# Duplicates by Fiscal Year + Department + Fund + Program: 364078

# %%
# Summary statistics for numeric-like columns
df.describe(include="all").T
# Out:
#                             count  unique  \
# Fiscal Year              379557.0     NaN
# Revenue or Spending        379557       2
# Related Govt Unit          379557       2
# Organization Group Code  379557.0     NaN
# Organization Group         379557       7
# Department Code            379557      69
# Department                 379557     120
# Program Code               379557     383
# Program                    379557     361
# Character Code             379557      98
# Character                  379557      80
# Object Code                379557     783
# Object                     379557     699
# Sub-object Code            379557    5640
# Sub-object                 379557    2978
# Fund Type Code             379557      36
# Fund Type                  379557      30
# Fund Code                  379557     566
# Fund                       379556     560
# Fund Category Code       379535.0     NaN
# Fund Category              379535      11
# Budget                     379557  102205
# data_as_of                 379557       1
# data_loaded_at             379557       1
#
#                                                              top    freq  \
# Fiscal Year                                                  NaN     NaN
# Revenue or Spending                                     Spending  315320
# Related Govt Unit                                       Spending  315320
# Organization Group Code                                      NaN     NaN
# Organization Group       Public Works, Transportation & Commerce  131704
# Department Code                                              DPW   41466
# Department                                      DPW Public Works   35150
# Program Code                                                 OPR  157516
# Program                                                Operating  157516
# Character Code                                    MAND_FRING_BEN   64047
# Character                              Mandatory Fringe Benefits  100441
# Object Code                                             HLTH_SVC   20345
# Object                                            Health Service   29003
# Sub-object Code                                            01701    3880
# Sub-object                          Social Security (OASDI & HI)    9791
# Fund Type Code                                          GEN_FUND   88805
# Fund Type                                           General Fund  148282
# Fund Code                                                  1GAGF   58579
# Fund                                                General Fund   58579
# Fund Category Code                                           NaN     NaN
# Fund Category                                          Operating  182188
# Budget                                                         0  168172
# data_as_of                                2025/09/14 10:06:00 PM  379557
# data_loaded_at                            2025/09/15 01:56:26 AM  379557
#
#                                 mean       std     min     25%     50%  \
# Fiscal Year              2019.450359   4.57164  2010.0  2016.0  2020.0
# Revenue or Spending              NaN       NaN     NaN     NaN     NaN
# Related Govt Unit                NaN       NaN     NaN     NaN     NaN
# Organization Group Code     3.428976  1.826104     1.0     2.0     3.0
# Organization Group               NaN       NaN     NaN     NaN     NaN
# Department Code                  NaN       NaN     NaN     NaN     NaN
# Department                       NaN       NaN     NaN     NaN     NaN
# Program Code                     NaN       NaN     NaN     NaN     NaN
# Program                          NaN       NaN     NaN     NaN     NaN
# Character Code                   NaN       NaN     NaN     NaN     NaN
# Character                        NaN       NaN     NaN     NaN     NaN
# Object Code                      NaN       NaN     NaN     NaN     NaN
# Object                           NaN       NaN     NaN     NaN     NaN
# Sub-object Code                  NaN       NaN     NaN     NaN     NaN
# Sub-object                       NaN       NaN     NaN     NaN     NaN
# Fund Type Code                   NaN       NaN     NaN     NaN     NaN
# Fund Type                        NaN       NaN     NaN     NaN     NaN
# Fund Code                        NaN       NaN     NaN     NaN     NaN
# Fund                             NaN       NaN     NaN     NaN     NaN
# Fund Category Code          2.089312  1.489393     0.0     1.0     1.0
# Fund Category                    NaN       NaN     NaN     NaN     NaN
# Budget                           NaN       NaN     NaN     NaN     NaN
# data_as_of                       NaN       NaN     NaN     NaN     NaN
# data_loaded_at                   NaN       NaN     NaN     NaN     NaN
#
#                             75%     max
# Fiscal Year              2023.0  2027.0
# Revenue or Spending         NaN     NaN
# Related Govt Unit           NaN     NaN
# Organization Group Code     5.0     7.0
# Organization Group          NaN     NaN
# Department Code             NaN     NaN
# Department                  NaN     NaN
# Program Code                NaN     NaN
# Program                     NaN     NaN
# Character Code              NaN     NaN
# Character                   NaN     NaN
# Object Code                 NaN     NaN
# Object                      NaN     NaN
# Sub-object Code             NaN     NaN
# Sub-object                  NaN     NaN
# Fund Type Code              NaN     NaN
# Fund Type                   NaN     NaN
# Fund Code                   NaN     NaN
# Fund                        NaN     NaN
# Fund Category Code          3.0     7.0
# Fund Category               NaN     NaN
# Budget                      NaN     NaN
# data_as_of                  NaN     NaN
# data_loaded_at              NaN     NaN

# %% [markdown]
# Off the bat we notice that "Budget" is an object, we'll need that as numerical later as well as a few other columns, for now this is just EDA.
